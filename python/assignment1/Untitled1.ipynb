# %%
class student:
    name="Sudhanshu Kumar"
    program="B.tech"
    Roll_no=121
    def printinfo(self):
        print(self.name,self.program,self.Roll_no)
a=student()
b=student()

# %%
a.name="Ayush"
a.program="B.tech"
a.Roll_no=23
b.name="Aman"
b.program="B.tech"
b.Roll_no=45

# %%
a.printinfo()b.printinfo()
# Out:
# Ayush B.tech 23
# Aman B.tech 45

# %%
# a=student()
print(a.name)
print(a.program)
print(a.Roll_no)
# Out:
# Sudhanshu Kumar
# B.tech
# 121

# %%
a=student()
a.name,a.program,a.Roll_no
# Out:
# ('Sudhanshu Kumar', 'B.tech', 121)

# %%
class book:
    def __init__(self,title,author):
        self.title=title
        self.author=author
    def display_info(self):
        print(f"title:{self.title},author:{self.author}")
class Ebook(book):
    def __init__(self,title,auhtor,format):
        super().__init__(title,auhtor)
        self.format=format
    def display_info(self):
        super().display_info()
        print(f"title:{self.title},author:{self.author},format:{self.format}")
book=Ebook("core python","dr.rao","pdf")
book.display_info()
# Out:
# title:core python,author:dr.rao
# title:core python,author:dr.rao,format:pdf

# %%
class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def display_info(self):
        print(f"Title: {self.title}")
        print(f"Author: {self.author}")
        print(f"Pages: {self.pages}")


class Ebook(Book):
    def __init__(self, title, author, pages, ebook_format):
        super().__init__(title, author, pages)
        self.format = ebook_format

    def display_info(self):
        super().display_info()
        print(f"Format: {self.format}")


# Example Usage:
book = Ebook("Python Programming", "John Doe", 300, "PDF")
book.display_info()
# Out:
# Title: Python Programming
# Author: John Doe
# Pages: 300
# Format: PDF
