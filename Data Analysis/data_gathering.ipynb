# %%
import pandas as pd

# %% [markdown]
# Opening a local csv file

# %%
df=pd.read_csv('Datasets/aug_train.csv')
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# Opening a csv file from an URL

# %%
import requests
from io import StringIO
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)
pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# Sep Parameter

# %%
pd.read_csv('Datasets/movie_titles_metadata.tsv',sep='\t', names=['sno','name','release_year','rating','votes','genres'])
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# Index_col parameter

# %%
pd.read_csv('Datasets/aug_train.csv', index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# Header parameter

# %%
pd.read_csv('Datasets/test.csv',header=1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# use_col parameter

# %%
pd.read_csv('Datasets/aug_train.csv',usecols=['enrollee_id','gender','education_level'])
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %% [markdown]
# Squeeze parameters

# %%
pd.read_csv('Datasets/aug_train.csv',usecols=['gender']).squeeze()
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: str

# %% [markdown]
# Skiprows/nrows Parameters

# %%
pd.read_csv('Datasets/aug_train.csv',skiprows=[0,1])
# Out:
#        29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0      11561   city_21               0.624   NaN   No relevent experience
# 1      33241  city_115               0.789   NaN   No relevent experience
# 2        666  city_162               0.767  Male  Has relevent experience
# 3      21651  city_176               0.764   NaN  Has relevent experience
# 4      28806  city_160               0.920  Male  Has relevent experience
# ...      ...       ...                 ...   ...                      ...
# 19151   7386  city_173               0.878  Male   No relevent experience
# 19152  31398  city_103               0.920  Male  Has relevent experience
# 19153  24576  city_103               0.920  Male  Has relevent experience
# 19154   5756   city_65               0.802  Male  Has relevent experience
# 19155  23834   city_67               0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM   15    50-99  \
# ...

# %%
pd.read_csv('Datasets/aug_train.csv',nrows=100)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# Encoding Parameter

# %%
pd.read_csv('Datasets/zomato.csv',encoding='latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# Skip bad Lines

# %%
pd.read_csv('Datasets/BX-Books.csv',sep=';', encoding='latin-1', on_bad_lines='warn')
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_4236\3528584711.py:1: ParserWarning: Skipping line 6451: expected 8 fields, saw 9
# Skipping line 43666: expected 8 fields, saw 10
# Skipping line 51750: expected 8 fields, saw 9
#
#   pd.read_csv('Datasets/BX-Books.csv',sep=';', encoding='latin-1', on_bad_lines='warn')
# C:\Users\sudha\AppData\Local\Temp\ipykernel_4236\3528584711.py:1: ParserWarning: Skipping line 92037: expected 8 fields, saw 9
# Skipping line 104318: expected 8 fields, saw 9
# Skipping line 121767: expected 8 fields, saw 9
#
#   pd.read_csv('Datasets/BX-Books.csv',sep=';', encoding='latin-1', on_bad_lines='warn')
# C:\Users\sudha\AppData\Local\Temp\ipykernel_4236\3528584711.py:1: ParserWarning: Skipping line 144057: expected 8 fields, saw 9
# Skipping line 150788: expected 8 fields, saw 9
# Skipping line 157127: expected 8 fields, saw 9
# Skipping line 180188: expected 8 fields, saw 9
# Skipping line 185737: expected 8 fields, saw 9
#
# ...

# %% [markdown]
# dtypes parameter

# %%
pd.read_csv('Datasets/aug_train.csv', dtype={'target':int})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# Hansling Dates

# %%
pd.read_csv('Datasets/IPL Matches 2008-2020.csv', parse_dates=['date'])
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# Convertors

# %%
def rename(name):
    if name=='Royal Challengers Bangalore':
        return "RCB"
    else:
        return name

# %%
pd.read_csv('Datasets/IPL Matches 2008-2020.csv', converters={'team1':rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# na_values parameter

# %%
pd.read_csv('Datasets/aug_train.csv', na_values=['Male'])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# Loading a huge dataset in chunks

# %%
dfs=pd.read_csv('Datasets/aug_train.csv', chunksize=5000)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)

# %% [markdown]
# Opening of excel file

# %%
# pd.read_excel('Datasets/output.xlsx', index_col='unnamed:0')

# %%
# pd.read_excel('Datasets/output.xlsx',sheet_name='sheet_name_2')

# %% [markdown]
# Open Text file

# %%
# pd.read_csv('Datasets/question_answer_paris.txt', sep='\t')

# %% [markdown]
# Opening the JSON file

# %%
# local json file
pd.read_json('Datasets/train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# json from url
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR")
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWG  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# Opening SQL files

# %%
# %pip install mysql.connector

# %%
import mysql.connector

# %%
# conn=mysql.connector.connect(
#     host='localhost',
#     user='root',
#     password='',
#     database='world'
# )

# %%
# pd.read_sql_query("SELECT * FROM city",conn)

# %%
# pd.read_sql_query("SELECT * FROM country",conn)

# %%
# pd.read_sql_query("SELECT * FROM countrylanguage",conn)

# %% [markdown]
# Pandas Export
# 1. to csv
# 2. to execl
# 3. to HTML
# 4. to JSON
# 5. to sql

# %% [markdown]
# to_csv

# %%
df=pd.read_csv('Datasets/deliveries.csv')
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
temp_df=df.groupby('batsman')['batsman_runs'].sum().reset_index()
temp_df
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4       A Dananjaya             4
# ..              ...           ...
# 511     YV Takawale           192
# 512   Yashpal Singh            47
# 513     Younis Khan             3
# 514    Yuvraj Singh          2765
# 515          Z Khan           117
#
# [516 rows x 2 columns]

# %%
temp_df.to_csv('Exported_Data/batsman_runs.csv')

# %%
df.pivot_table(index='batsman',columns='bowling_team',values='batsman_runs',aggfunc='sum').to_csv('Exported_Data/batsman_vs_team.csv')

# %% [markdown]
# to_excel

# %%
# %pip install openpyxl

# %%
temp_df=df.groupby('batsman')['batsman_runs'].sum().reset_index()

# %%
temp_df.to_excel('Exported_Data/batsman_runs.xlsx')

# %%
temp_df2=df.pivot_table(index='batsman',columns='bowling_team',values='batsman_runs',aggfunc='sum')

# %%
with pd.ExcelWriter('Exported_Data/batsman_runs.xlsx') as writer:
    temp_df.to_excel(writer, sheet_name='Sheet_name_1')
    temp_df2.to_excel(writer, sheet_name='Sheet_name_2')

# %% [markdown]
# to_html

# %%
df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df.query('batsman_runs==6').pivot_table(index='over',columns='ball',values='batsman_runs',aggfunc='count').to_html('Exported_Data/sixes_heatmap.html')

# %% [markdown]
# to_json

# %%
json=df.groupby(['batting_team','batsman'])['batsman_runs'].sum().unstack()

# %%
json.to_json('Exported_Data/ipl.json')

# %% [markdown]
# to_sql

# %%
df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
# %pip install pymysql
# %pip install sqlalchemy

# %%
import pymysql
from sqlalchemy import create_engine

# %%
engine=create_engine("mysql+pymysql://root:TCA2357052@localhost/ipl")
#{root}:{password}@{URL}/{database}
df.to_sql('ipl_delivery',con=engine, if_exists='append')
# Out:
# 179078

# %%
temp_df
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4       A Dananjaya             4
# ..              ...           ...
# 511     YV Takawale           192
# 512   Yashpal Singh            47
# 513     Younis Khan             3
# 514    Yuvraj Singh          2765
# 515          Z Khan           117
#
# [516 rows x 2 columns]

# %%
temp_df.to_sql('batsman_runs', con=engine, if_exists='append')
# Out:
# 516

# %%
six_df=df.query('batsman_runs==6').pivot_table(index='over',columns='ball',values='batsman_runs',aggfunc='count')

# %%
six_df
# Out:
# ball     1      2      3      4      5      6     7    8    9
# over
# 1      7.0   12.0   27.0   31.0   24.0   20.0  12.0  1.0  NaN
# 2     26.0   30.0   35.0   43.0   45.0   42.0  10.0  5.0  NaN
# 3     63.0   46.0   57.0   52.0   48.0   58.0   8.0  2.0  1.0
# 4     49.0   61.0   51.0   81.0   54.0   53.0  11.0  1.0  NaN
# 5     54.0   56.0   82.0   64.0   62.0   60.0  10.0  2.0  NaN
# 6     61.0   82.0   44.0   65.0   56.0   66.0  11.0  1.0  NaN
# 7     27.0   45.0   34.0   44.0   51.0   28.0   3.0  3.0  NaN
# 8     44.0   47.0   55.0   49.0   53.0   39.0   7.0  NaN  NaN
# 9     70.0   56.0   56.0   58.0   52.0   35.0  11.0  NaN  1.0
# 10    43.0   38.0   60.0   43.0   52.0   54.0   9.0  1.0  NaN
# 11    59.0   70.0   62.0   54.0   61.0   56.0   8.0  NaN  NaN
# 12    70.0   58.0   72.0   63.0   65.0   52.0  11.0  1.0  NaN
# 13    67.0   87.0   58.0   80.0   75.0   65.0  10.0  2.0  NaN
# 14    83.0   85.0   79.0   74.0   65.0   71.0   7.0  3.0  NaN
# ...

# %%
six_df.to_sql('six_hitmap', con=engine, if_exists='append')
# Out:
# 20

# %% [markdown]
# Taking dataset from API

# %%
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwYWI4Y2E3MmZhZmM2MDU0NjhkMDJmN2E0NGMyMTFmZSIsIm5iZiI6MTc4MTk1OTAyNC43MzIsInN1YiI6IjZhMzY4OTcwNjhlYjM1YjQ3NDIzYjhiMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.2L_QHoka-kzkVj6KMFCafsk7t5lSZXJ3CeeWBBSUhhU"
}

response = requests.get(url, headers=headers)

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#         id                     title  \
# 0  1007757                   Swapped
# 1      278  The Shawshank Redemption
# 2   687163         Project Hail Mary
# 3      238             The Godfather
# 4   936075                   Michael
#
#                                             overview release_date  popularity  \
# 0  A small woodland creature and a majestic bird,...   2026-05-01    153.6512
# 1  Imprisoned in the 1940s for the double murder ...   1994-09-23     68.7965
# 2  Science teacher Ryland Grace wakes up on a spa...   2026-03-15    133.9242
# 3  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     38.1178
# 4  The story of Michael Jackson, one of the most ...   2026-04-22    535.6645
#
#    vote_average  vote_count
# 0         8.971        1724
# 1         8.723       30586
# 2         8.684        5214
# 3         8.700       23052
# 4         8.657        2694

# %%
df=pd.DataFrame()

# %%
for i in range(1, 5):
    url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}"

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwYWI4Y2E3MmZhZmM2MDU0NjhkMDJmN2E0NGMyMTFmZSIsIm5iZiI6MTc4MTk1OTAyNC43MzIsInN1YiI6IjZhMzY4OTcwNjhlYjM1YjQ3NDIzYjhiMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.2L_QHoka-kzkVj6KMFCafsk7t5lSZXJ3CeeWBBSUhhU"
    }

    response = requests.get(url, headers=headers)

    temp_df = pd.DataFrame(response.json()['results'])[
        ['id', 'title', 'overview', 'release_date',
         'popularity', 'vote_average', 'vote_count']
    ]

    df = pd.concat([df, temp_df], ignore_index=True)

print(df.shape)
# Out:
# (140, 7)

# %%
df
# Out:
#           id                          title  \
# 0    1007757                        Swapped
# 1        278       The Shawshank Redemption
# 2     687163              Project Hail Mary
# 3        238                  The Godfather
# 4     936075                        Michael
# ..       ...                            ...
# 135   652837  Josee, the Tiger and the Fish
# 136    77338               The Intouchables
# 137       28                 Apocalypse Now
# 138   654299      Out of the Clear Blue Sky
# 139  1139087             Once Upon a Studio
#
#                                               overview release_date  \
# 0    A small woodland creature and a majestic bird,...   2026-05-01
# 1    Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2    Science teacher Ryland Grace wakes up on a spa...   2026-03-15
# 3    Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 4    The story of Michael Jackson, one of the most ...   2026-04-22
# ...

# %%
df.to_csv('Exported_Data/movies.csv')
