# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Datasets/train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Column Types
# - Numerical - Age,Fare,PassengerId
# - Categorical - Survived, Pclass, Sex, SibSp, Parch,Embarked
# - Mixed - Name, Ticket, Cabin

# %% [markdown]
# ### Univariate Analysis on Numerical columns

# %% [markdown]
# ### Age
# **conclusions**
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers

# %%
# Get statistical value
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# get visualization
df['Age'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Check skewness(closer the value to zero normal the data is)
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
# Find the outliar
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
# Check if outliers are correct
df[df['Age']>65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
# find the null values
df['Age'].isnull().sum()/len(df['Age'])
# Out:
# np.float64(0.19865319865319866)

# %% [markdown]
# ### Fare
# **Conclusion**
# - The data is highly(positively) skewed
# - Fare col actually contains the group fare and not the individual fare(This might be and issue)
# - We need to create a new col colled individaul fare

# %%
# Get statistical value
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# get visualization
df['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Check skewness(closer the value to zero normal the data is)
df['Fare'].skew()
# Out:
# np.float64(4.787316519674893)

# %%
# Find the outliar
df['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
# Check if outliers are correct
df[df['Fare']>250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
# find the null values
df['Fare'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Univariate Analysis on categorical columns

# %% [markdown]
# ### Survived
# **Conclusion**
# - no missing value
# - survial rate is less than 40%

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
df['Survived'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Pclass
# **conclusion**
# - why the 1st class why more passenger(check needed)

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%0.001f%%')
# Out:
# <Axes: >

# %%
df['Survived'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Sex
# **conclusion**
# - no problem detected

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
df['Sex'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### SibSp/Parch
# **conclusion**
# - Parch and SibSp columns can be merged to form a new column family size
# - Create a new column called is_alone

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['SibSp'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
df['SibSp'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['Parch'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Parch'>

# %%
df['Parch'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
df['Parch'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Embarked
# **Conclusion**
# - 2 missing values

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: >

# %%
df['Embarked'].isna().sum()
# Out:
# np.int64(2)

# %% [markdown]
# ### Univariate Analysis on Mixed columns
# - need to do feaature engineering to extract more insight

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# **conclusion**
# - travelling in 3rd pclass is most risky(chance for survival is less)
# - Chance of female survival is more

# %%
# Survived and Pclass
pd.crosstab(df['Survived'],df['Pclass'], normalize='columns')*100
# conclusion
# travelling in 3rd pclass is most risky(chance for survival is less)
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
# survived and Sex
pd.crosstab(df['Survived'],df['Sex'], normalize='columns')*100
# conclusion
# Chance of female survival is more
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
# Survived and Embarked
pd.crosstab(df['Survived'],df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df['Sex'],df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df['Pclass'],df['Embarked'], normalize='columns')*100
# conclusion
# The analysis shows that the most people in 1st class are from "c". That's why the passenger boarded at "c" have high survival rate
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
# survived and age
df[df['Survived']==1]['Age'].plot(kind='kde', label='Survived', grid=True) 
df[df['Survived']==0]['Age'].plot(kind='kde', label='Not Survived', grid=True) 
plt.legend()
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df['SibSp']==8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df['Ticket']=='CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df['Name'].str.contains('Sage')]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df1=pd.read_csv('Datasets/test.csv')

# %%
df=pd.concat([df,df1],ignore_index=True)

# %%
df[df['Ticket']=='CA. 2343']
# Out:
#       PassengerId  Survived  Pclass                               Name  \
# 159           160       0.0       3         Sage, Master. Thomas Henry
# 180           181       0.0       3       Sage, Miss. Constance Gladys
# 201           202       0.0       3                Sage, Mr. Frederick
# 324           325       0.0       3           Sage, Mr. George John Jr
# 792           793       0.0       3            Sage, Miss. Stella Anna
# 846           847       0.0       3           Sage, Mr. Douglas Bullen
# 863           864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"
# 1079         1080       NaN       3                    Sage, Miss. Ada
# 1233         1234       NaN       3              Sage, Mr. John George
# 1251         1252       NaN       3        Sage, Master. William Henry
# 1256         1257       NaN       3     Sage, Mrs. John (Annie Bullen)
#
#          Sex   Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# ...

# %%
df['Individual_fare']=df['Fare']/(df['SibSp']+df['Parch']+1)

# %%
df['Individual_fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[['Individual_fare','Fare']].describe()
# Out:
#        Individual_fare         Fare
# count      1308.000000  1308.000000
# mean         20.518215    33.295479
# std          35.774337    51.758668
# min           0.000000     0.000000
# 25%           7.452767     7.895800
# 50%           8.512483    14.454200
# 75%          24.237500    31.275000
# max         512.329200   512.329200

# %%
df['Family_size']=df['SibSp']+df['Parch']+1

# %%
# family_type
# 1 -> alone
# 2-4 -> small
# >5 -> large

def transform_family_size(num):
    if num==1:
        return 'alone'
    elif num>1 and num<5:
        return 'small'
    else:
        return 'large'

# %%
df['Family_type']=df['Family_size'].apply(transform_family_size)

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Survived and Embarked
pd.crosstab(df['Survived'],df['Family_type'], normalize='columns')*100
# Out:
# Family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %%
df['Surname']=df['Name'].str.split(',').str.get(0)

# %%
df['Title']=df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr.          757
# Miss.        260
# Mrs.         197
# Master.       61
# Rev.           8
# Dr.            8
# Col.           4
# Ms.            2
# Major.         2
# Mlle.          2
# Don.           1
# Mme.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Dona.          1
# Name: count, dtype: int64

# %%
df['Title']=df['Title'].str.replace('Rev.','Other')
df['Title']=df['Title'].str.replace('Dr.','Other')
df['Title']=df['Title'].str.replace('Col.','Other')
df['Title']=df['Title'].str.replace('Major.','Other')
df['Title']=df['Title'].str.replace('Don.','Other')
df['Title']=df['Title'].str.replace('Capt.','Other')
df['Title']=df['Title'].str.replace('the.','Other')
df['Title']=df['Title'].str.replace('Jonkheer.','Other')

# %%
temp_df=df[df['Title'].isin(['Mr.','Miss.','Mrs.','Master.','Other'])]

# %%
pd.crosstab(temp_df['Survived'],df['Title'], normalize='columns')*100
# Out:
# Title     Master.     Miss.        Mr.  Mrs.  Other
# Survived
# 0.0          42.5  30.21978  84.332689  20.8   75.0
# 1.0          57.5  69.78022  15.667311  79.2   25.0

# %%
df['Cabin'].isnull().sum()/len(df['Cabin'])
# Out:
# np.float64(0.774637127578304)

# %%
df.fillna({'Cabin': 'M'}, inplace=True)
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# df['Cabin'].fillna('M', inplace=True)

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# M                  1014
# C23 C25 C27           6
# G6                    5
# B57 B59 B63 B66       5
# F33                   4
#                    ...
# C39                   1
# B24                   1
# D40                   1
# D38                   1
# C105                  1
# Name: count, Length: 187, dtype: int64

# %%
df['Deck']=df['Cabin'].str[0]

# %%
df['Deck'].value_counts()
# Out:
# Deck
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: count, dtype: int64

# %%
pd.crosstab(df['Deck'],df['Pclass'])
# Out:
# Pclass   1    2    3
# Deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df['Deck'],df['Survived'],normalize='index').plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Deck'>

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.dtypes
# Out:
# PassengerId          int64
# Survived           float64
# Pclass               int64
# Name                   str
# Sex                    str
# Age                float64
# SibSp                int64
# Parch                int64
# Ticket                 str
# Fare               float64
# Cabin                  str
# Embarked               str
# Individual_fare    float64
# Family_size          int64
# Family_type            str
# Surname             object
# Title               object
# Deck                   str
# dtype: object

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.pairplot(df1)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
